# %% [markdown]
# # Tutorial How-To
#
# This tutorial requires this initial notebook to be run first so that the requirements and environment variables are stored for all notebooks in the workshop

# %% [markdown]
# ## How to get started
#
# 1. Clone this repository to your local machine.
#
# 2. Install the required dependencies by running the following command:

# %%
# !ls -l
# !ls -l ../
# Out:
# total 8
# drwxr-xr-x 5 root root 4096 Oct 27 04:28 prompt-eng-interactive-tutorial
# drwxr-xr-x 1 root root 4096 Oct 23 13:40 sample_data
# total 448
# lrwxrwxrwx   1 root root      7 Jun 27  2024 bin -> usr/bin
# drwxr-xr-x   2 root root   4096 Apr 18  2022 boot
# drwxr-xr-x   1 root root   4096 Oct 27 04:28 content
# -rw-r--r--   1 root root   4332 Jul 10  2024 cuda-keyring_1.1-1_all.deb
# drwxr-xr-x   1 root root   4096 Oct 23 13:54 datalab
# drwxr-xr-x   5 root root    360 Oct 27 04:27 dev
# drwxr-xr-x   1 root root   4096 Oct 27 04:27 etc
# drwxr-xr-x   2 root root   4096 Apr 18  2022 home
# drwxr-xr-x   3 root root   4096 Oct 27 04:27 kaggle
# lrwxrwxrwx   1 root root      7 Jun 27  2024 lib -> usr/lib
# lrwxrwxrwx   1 root root      9 Jun 27  2024 lib32 -> usr/lib32
# lrwxrwxrwx   1 root root      9 Jun 27  2024 lib64 -> usr/lib64
# lrwxrwxrwx   1 root root     10 Jun 27  2024 libx32 -> usr/libx32
# drwxr-xr-x   2 root root   4096 Jun 27  2024 media
# drwxr-xr-x   2 root root   4096 Jun 27  2024 mnt
# -rw-r--r--   1 root root  17294 Jul 10  2024 NGC-DL-CONTAINER-LICENSE
# drwxr-xr-x   1 root root   4096 Oct 23 14:12 opt
# dr-xr-xr-x 187 root root      0 Oct 27 04:27 proc
# drwxrwxr-x  14 root root   4096 Oct 23 13:23 python-apt
# -r-xr-xr-x   1 root root 346012 Jan  1  2000 python-apt.tar.xz
# drwx------   1 root root   4096 Oct 27 04:27 root
# drwxr-xr-x   1 root root   4096 Oct 23 13:16 run
# lrwxrwxrwx   1 root root      8 Jun 27  2024 sbin -> usr/sbin
# drwxr-xr-x   2 root root   4096 Jun 27  2024 srv
# dr-xr-xr-x  13 root root      0 Oct 27 04:27 sys
# drwxrwxrwt   1 root root   4096 Oct 27 04:33 tmp
# drwxr-xr-x   1 root root   4096 Oct 23 13:54 tools
# drwxr-xr-x   1 root root   4096 Oct 23 13:56 usr
# drwxr-xr-x   1 root root   4096 Oct 23 13:55 var

# %%
# %pip install -qU pip
# %pip install -qr prompt-eng-interactive-tutorial/AmazonBedrock/requirements.txt
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.16 which is incompatible.

# %% [markdown]
# 3. Restart the kernel after installing dependencies

# %%
# restart kernel
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %% [markdown]
# ---
#
# ## Usage Notes & Tips 💡
#
# - This course uses Claude 3 Haiku with temperature 0. We will talk more about temperature later in the course. For now, it's enough to understand that these settings yield more deterministic results. All prompt engineering techniques in this course also apply to previous generation legacy Claude models such as Claude 2 and Claude Instant 1.2.
#
# - You can use `Shift + Enter` to execute the cell and move to the next one.
#
# - When you reach the bottom of a tutorial page, navigate to the next numbered file in the folder, or to the next numbered folder if you're finished with the content within that chapter file.
#
# ### The Anthropic SDK & the Messages API
# We will be using the [Anthropic python SDK](https://docs.anthropic.com/claude/reference/claude-on-amazon-bedrock) and the [Messages API](https://docs.anthropic.com/claude/reference/messages_post) throughout this tutorial.
#
# Below is an example of what running a prompt will look like in this tutorial.

# %% [markdown]
# First, we set and store the model name and region.

# %%
import boto3
# create a boto3 session to dynamically get and set the region name
AWS_REGION = boto3.Session().region_name
print("AWS Region:", AWS_REGION)
MODEL_NAME = "anthropic.claude-3-haiku-20240307-v1:0"

# %store MODEL_NAME
# %store AWS_REGION
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2732598724.py in <cell line: 0>()
#       1 import boto3
#       2 # create a boto3 session to dynamically get and set the region name
# ----> 3 AWS_REGION = boto3.Session().me-south-1
#       4 print("AWS Region:", AWS_REGION)
#       5 MODEL_NAME = "anthropic.claude-3-haiku-20240307-v1:0"
#
# AttributeError: 'Session' object has no attribute 'me'

# %%
# %env AWS_REGION = "me-central-1"
# Out:
# env: AWS_REGION="me-central-1"

# %% [markdown]
# Then, we create `get_completion`, which is a helper function that sends a prompt to Claude and returns Claude's generated response. Run that cell now.

# %%
from anthropic import AnthropicBedrock

# Initialize the client
client = AnthropicBedrock(aws_region=AWS_REGION)

def get_completion(prompt, system=''):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ],
        system=system
    )
    return message.content[0].text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1899884342.py in <cell line: 0>()
#       2
#       3 # Initialize the client
# ----> 4 client = AnthropicBedrock(aws_region=AWS_REGION)
#       5
#       6 def get_completion(prompt, system=''):
#
# /usr/local/lib/python3.12/dist-packages/anthropic/lib/bedrock/_client.py in __init__(self, aws_secret_key, aws_access_key, aws_region, aws_session_token, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     122             base_url = f"https://bedrock-runtime.{self.aws_region}.amazonaws.com"
#     123
# --> 124         super().__init__(
#     125             version=__version__,
#     126             base_url=base_url,
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in __init__(self, version, base_url, max_retries, timeout, transport, proxies, limits, http_client, custom_headers, custom_query, _strict_response_validation)
#     799             _strict_response_validation=_strict_response_validation,
#     800         )
# --> 801         self._client = http_client or SyncHttpxClientWrapper(
#     802             base_url=base_url,
#     803             # cast to a valid type because mypy doesn't understand our type narrowing
#
# TypeError: Client.__init__() got an unexpected keyword argument 'proxies'

# %% [markdown]
# Now we will write out an example prompt for Claude and print Claude's output by running our `get_completion` helper function. Running the cell below will print out a response from Claude beneath it.
#
# Feel free to play around with the prompt string to elicit different responses from Claude.

# %%
# Prompt
prompt = "Hello, Claude!"

# Get Claude's response
print(get_completion(prompt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1528239814.py in <cell line: 0>()
#       3
#       4 # Get Claude's response
# ----> 5 print(get_completion(prompt))
#
# NameError: name 'get_completion' is not defined

# %% [markdown]
# The `MODEL_NAME` and `AWS_REGION` variables defined earlier will be used throughout the tutorial. Just make sure to run the cells for each tutorial page from top to bottom.
